# %%
#i have a little knowledge about python, that i learnt on my own from youtube tutorials. i want to tell you beforehand.

#prob.1

x=1
y=2

#defining the type of variables that is integers.

type(x)
type(y)
# Out:
# int

# %%
#swapping values:

x=x+y
y=x-y
x=x-y

#printing the swapped values.

print("after swap")
print("x is", x)
print("y is", y)
# Out:
# after swap
# x is 2
# y is 1

# %%
#prob.2

#dimentions of a rectangle, taking input as integers:
Length= int(input('Length of rectangle:'))
Width= int(input('Width of rectangle:'))
# Out:
# Length of rectangle: 5
# Width of rectangle: 6

# %%
#area of a rectangle: Length*Width
area= Length*Width
print("Area of Rectangle is", area)
# Out:
# Area of Rectangle is 30

# %%
#prob.3

#about converting temprature from celsius to Farenheit:
#The formula to convert Celsius to Fahrenheit is: °F = °C × (9/5) + 32

#taking integer input from user.
C= int(input('Celsius in degree:' ))

#converting in Fahrenheit:
Fahrenheit=C*(9/5)+32
print(Fahrenheit, "degree Fahrenheit")
# Out:
# Celsius in degree: 15
# 59.0 degree Fahrenheit

# %%
#string based questions:
#prob.1

#taking input from user:
string= str(input())

#printing the length of the user given string:
print("length of the above string is", len(string))
# Out:
#  how are you
# length of the above string is 11

# %%
#prob.2- counting the vowels

#this problem was toughest from all. it took me significant time to solve this. i have researched the solution on my own. and it comes with for loop.
#so i didn't  proceed with the solution.

# %%
#prob.3

#getting input from user:
string= str(input('type: '))

#reversing the string:
reverse=string[ : :-1]
print(reverse)
# Out:
# type:  how are you?
# ?uoy era woh

# %%
#prob.4

#getting user input:
string= str(input('type: '))

#reversing to check if it is a palindrome:
reverse=string[ : :-1]

#putting a if else statement as per the problem to check the answer.
if string==reverse:
    print("matched")
else:
    print("not matched")
# Out:
# type:  lol
# matched

# %%
#prob.5
string= str(input("type here: "))

#removing the spaces:

without_space= string.replace(" ", "")
print(without_space)
# Out:
# type here:  hello, how are you?
# hello,howareyou?

# %%
#end of assignment.
